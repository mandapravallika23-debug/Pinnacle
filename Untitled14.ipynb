# %% [markdown]
# <a href="https://colab.research.google.com/github/mandapravallika23-debug/Pinnacle/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile CurrencyConverter.java
#
# import java.util.Scanner;
#
# public class CurrencyConverter {
#     public static void main(String[] args) {
#         Scanner sc = new Scanner(System.in);
#
#         System.out.print("Enter amount in INR: ");
#         double inr = sc.nextDouble();
#
#         double usd = inr / 83.0;
#         double eur = inr / 90.0;
#         double gbp = inr / 105.0;
#
#         System.out.println("USD: " + usd);
#         System.out.println("EUR: " + eur);
#         System.out.println("GBP: " + gbp);
#
#         sc.close();
#     }
# }
# Out:
# Writing CurrencyConverter.java

# %%
# !javac CurrencyConverter.java

# %%
# !echo "1000" | java CurrencyConverter
# Out:
# Enter amount in INR: USD: 12.048192771084338
# EUR: 11.11111111111111
# GBP: 9.523809523809524
